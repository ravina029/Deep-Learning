# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('/Users/ravina/Desktop/StudentsPerformance (1).csv')

# %%
df1.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
df=df1[["reading score","writing score",'gender','math score']]

# %%
df.head()
# Out:
#    reading score  writing score  gender  math score
# 0             72             74  female          72
# 1             90             88  female          69
# 2             95             93  female          90
# 3             57             44    male          47
# 4             78             75    male          76

# %%
df['gender']=pd.get_dummies(df['gender'],drop_first=True)

# %%
df.head(5)
# Out:
#    reading score  writing score  gender  math score
# 0             72             74       0          72
# 1             90             88       0          69
# 2             95             93       0          90
# 3             57             44       1          47
# 4             78             75       1          76

# %%
import seaborn as sns

# %%
sns.scatterplot(x='writing score', y='math score', hue='gender', data=df)

# Show the plot
plt.show()

# %%
df_rough=df.iloc[:,1:]

# %%
df_rough.head(4)
# Out:
#    writing score  gender  math score
# 0             74       0          72
# 1             88       0          69
# 2             93       0          90
# 3             44       1          47

# %%
X=df_rough.drop('gender',axis=1)
y=df_rough[['gender']]

# %%
X.head(3)
# Out:
#    writing score  math score
# 0             74          72
# 1             88          69
# 2             93          90

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-1147.,  1063.]])

# %%
p.intercept_
# Out:
# array([130.])

# %%
! pip install mlxtend
# Out:
# ...
#   Obtaining dependency information for mlxtend from https://files.pythonhosted.org/packages/1c/07/512f6a780239ad6ce06ce2aa7b4067583f5ddcfc7703a964a082c706a070/mlxtend-0.23.1-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.7 MB/s eta 0:00:00a 0:00:010m
# ...

# %%
from mlxtend.plotting import plot_decision_regions

# %%
y_1d = np.ravel(y.values) #converting y into 1d array

# %%
plot_decision_regions(X.values,y_1d,clf=p,legend=2)
# Out:
# <Axes: >
